# %%
import numpy as np
from scipy.special import sph_harm
import plotly.graph_objects as go

def sph_harm_figure(l, m):
    """Create a figure of Y_lm using Plotly."""

    # Define the 1-dimensional coordinate axes:
    thetas = np.linspace(0, np.pi, 100)
    phis = np.linspace(0, 2*np.pi, 100)
    
    
    # Make a 2D-meshed grid out of the axes:
    Theta, Phi = np.meshgrid(thetas, phis, indexing="ij")
    
    ylm = sph_harm(m, l, Phi, Theta)

    fcolors = ylm.real
    fmax, fmin = fcolors.max(), fcolors.min()
    fcolors = (fcolors - fmin)/(fmax - fmin)

    R = abs(ylm)
    X = R * np.sin(Theta) * np.cos(Phi)
    Y = R * np.sin(Theta) * np.sin(Phi)
    Z = R * np.cos(Theta)

    
    fig = go.Figure(
                data=[
                    go.Surface(
                        x=X, y=Y, z=Z, 
                        surfacecolor=fcolors,
                        colorscale='balance', showscale=False, 
                        opacity=1.0, hoverinfo='none',
                    )
                ]
    )

    fig.update_layout(title='$Y_{%d%d}$' % (l, m), autosize=False,
                      width=700, height=700,
                      margin=dict(l=65, r=50, b=65, t=90)
    )
    
    return fig

# %%
sph_harm_figure(4,2)
# Out:
# <div>                            <div id="3d144646-8f5d-4a5e-843d-ac732f7f3136" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d144646-8f5d-4a5e-843d-ac732f7f3136")) {                    Plotly.newPlot(                        "3d144646-8f5d-4a5e-843d-ac732f7f3136",                        [{"colorscale":[[0.0,"rgb(23, 28, 66)"],[0.09090909090909091,"rgb(41, 58, 143)"],[0.18181818181818182,"rgb(11, 102, 189)"],[0.2727272727272727,"rgb(69, 144, 185)"],[0.36363636363636365,"rgb(142, 181, 194)"],[0.45454545454545453,"rgb(210, 216, 219)"],[0.5454545454545454,"rgb(230, 210, 204)"],[0.6363636363636364,"rgb(213, 157, 137)"],[0.7272727272727273,"rgb(196, 101, 72)"],[0.8181818181818182,"rgb(172, 43, 36)"],[0.9090909090909091,"rgb(120, 14, 40)"],[1.0,"rgb(60, 9, 17)"]],"hoverinfo":"none","opacity":1.0,"showscale":false,"surfacecolor":[[0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221,0.4998741039041221],[0.5022238457064166,0.5022049415938179,0.5021485334302699,0.5020555288442398,0.501927424314332,0.5017662810903873,0.5015746920272011,0.5013557398645189,0.5011129476246008,0.5008502219254733,0.5005717901219839,0.5002821322860784,0.4999859091207664,0.4996878869676657,0.49939286111478065,0.49910557863852384,0.49883066202147897,0.49857253477492625,0.49833535026288955,0.49812292487295495,0.4979386766091653,0.49778557009505636,0.49766606887175374,0.4975820957586742,0.4975350019146416,0.4975255450972354,0.4975538774701879,0.4976195431550122,0.49772148556625834,0.4978580644123685,0.49802708208858193,0.4982258190372187,0.49845107750638024,0.4986992330029748,0.49896629261216824,0.49924795924487775,0.49953970077954457,0.4998368229856658,0.5001345450557205,0.5004280765301531,0.5007126943776595,0.5009838189905301,0.5012370878722513,0.5014684258317081,0.5016741105545343,0.5018508324965435,0.5019957481355353,0.5021065257246307,0.5021813828109529,0.502219114915961,0.502219114915961,0.5021813828109529,0.5021065257246307,0. ...
